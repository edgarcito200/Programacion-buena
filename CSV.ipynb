# %% [markdown]
# <a href="https://colab.research.google.com/github/edgarcito200/Programacion-buena/blob/main/CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !python --version
# !apt-get install python3.12
# Out:
# ...
# Python 3.10.12
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.12-stdlib mailcap mime-support
# Suggested packages:
#   python3.12-venv
# The following NEW packages will be installed:
#   libpython3.12-stdlib mailcap mime-support python3.12
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 5,442 kB of archives.
# After this operation, 22.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 mailcap all 3.70+nmu1ubuntu1 [23.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 mime-support all 3.66 [3,696 B]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.12-stdlib amd64 3.12.8-1+jammy1 [2,889 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.12 amd64 3.12.8-1+jammy1 [2,526 kB]
# ...

# %%
from google.colab import files
archivo_subido = files.upload()
nombre_archivo = list(archivo_subido.keys())[0]
with open(nombre_archivo, 'r', encoding='utf-8') as archivo:
    contenido = archivo.read()
print(contenido)
# Out:
#      <input type="file" id="files-4902b169-6278-468c-8f7e-ce920a50556f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4902b169-6278-468c-8f7e-ce920a50556f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
archivo_subido = files.upload()
nombre_archivo = list(archivo_subido.keys())[0]
df = pd.read_csv(nombre_archivo)
(df)
# Out:
#      <input type="file" id="files-c62df7bc-e91a-4e00-8ec4-798d41183d8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c62df7bc-e91a-4e00-8ec4-798d41183d8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
n2 = df["State"].str.contains("Russian Federation")
n2.value_counts()
n2[n2==True].count().sum()
# Out:
# 30

# %%
n2 = df["State"].str.contains("China")
n2.value_counts()
n2[n2==True].count().sum()
# Out:
# 82

# %%
n2 = df["State"].str.contains("USA")
n2.value_counts()
n2[n2==True].count().sum()
# Out:
# 362

# %%
n2 = df["State"].str.contains("ESA")
n2.value_counts()
n2[n2==True].count().sum()
# Out:
# 2

# %%
n2 = df["Status"].str.contains("in orbit")
n2.value_counts()
n2[n2==True].count().sum()
# Out:
# 201

# %%
n2 = df["Status"].str.contains("decayed")
n2.value_counts()
n2[n2==True].count().sum()
# Out:
# 253

# %%
n2 = df.loc[df['International Designator'].str.contains('2019-092F')]
n2["Date of Decay or Change"]
# Out:
# 19    [2024-05-22]
# Name: Date of Decay or Change, dtype: object
