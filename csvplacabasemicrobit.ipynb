# %% [markdown]
# <a href="https://colab.research.google.com/github/edgarcito200/Programacion-buena/blob/main/csvplacabasemicrobit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !python --version
# !apt-get install python3.12
# Out:
# ...
# Python 3.10.12
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.12-stdlib mailcap mime-support
# Suggested packages:
#   python3.12-venv
# The following NEW packages will be installed:
#   libpython3.12-stdlib mailcap mime-support python3.12
# 0 upgraded, 4 newly installed, 0 to remove and 49 not upgraded.
# Need to get 5,442 kB of archives.
# After this operation, 22.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 mailcap all 3.70+nmu1ubuntu1 [23.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 mime-support all 3.66 [3,696 B]
# Get:3 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.12-stdlib amd64 3.12.8-1+jammy1 [2,889 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.12 amd64 3.12.8-1+jammy1 [2,526 kB]
# ...

# %%
from google.colab import files
import pandas as pd
archivo_subido = files.upload()
nombre_archivo = list(archivo_subido.keys())[0]
df = pd.read_csv(nombre_archivo)
df
# Out:
#      <input type="file" id="files-f138a535-cd8d-43dc-ab8c-54de3da0733d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f138a535-cd8d-43dc-ab8c-54de3da0733d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
max_u = df['A14: Temp'].max()
print("El màxim de tempertura a l'aula A14 és", max_u, "ºC")
min_u = df['A14: Temp'].min()
print("El mínim de tempertura a l'aula A14 és", min_u, "ºC")
# Out:
# El màxim de humitat a l'aula A14 és Humitat50.00% ºC
# El mínim de humitat a l'aula A14 és Humitat50.00% ºC

# %%
max_u = df['A14: Humitat'].max()
print("El màxim de humitat a l'aula A14 és", max_u, "%")
min_u = df['A14: Humitat'].min()
print("El mínim de humitat a l'aula A14 és", min_u, "%")
# Out:
# El màxim de tempertura a l'aula A14 és Temperatura25.00ºC %
# El mínim de tempertura a l'aula A14 és Temperatura25.00ºC %

# %%
max_u = df['Pati: Temp'].max()
print("El màxim de tempertura al Pati és", max_u, "ºC")
min_u = df['Pati: Temp'].min()
print("El mínim de tempertura al Pati és", min_u, "ºC")
# Out:
# El màxim de tempertura al Pati és Temperatura29.00ºC ºC
# El mínim de tempertura al Pati és Temperatura29.00ºC ºC

# %%
max_u = df['Pati: Humitat'].max()
print("El màxim de humitat al Pati és", max_u, "%")
min_u = df['Pati: Humitat'].min()
print("El mínim de humitat al Pati és", min_u, "%")
# Out:
# El màxim de humitat al Pati és Humitat38.00% %
# El mínim de humitat al Pati és Humitat38.00% %

# %%
max_u = df['Bany: Temp'].max()
print("El màxim de tempertura al Bany és", max_u, "ºC")
min_u = df['Bany: Temp'].min()
print("El mínim de tempertura al Bany és", min_u, "ºC")
# Out:
# El màxim de tempertura al Bany és Temperatura22.00ºC ºC
# El mínim de tempertura al Bany és Temperatura22.00ºC ºC

# %%
max_u = df['Bany: Humitat'].max()
print("El màxim de humitat al Bany és", max_u, "%")
min_u = df['Bany: Humitat'].min()
print("El mínim de humitat al Bany és", min_u, "%")
# Out:
# El màxim de humitat al Bany és humitat49.00% %
# El mínim de humitat al Bany és humitat48.00% %

# %%
max_u = df['Sala Profe: Temp'].max()
print("El màxim de tempertura a la Sala Profe és", max_u, "ºC")
min_u = df['Sala Profe: Temp'].min()
print("El mínim de tempertura a la Sala Profe és", min_u, "ºC")
# Out:
# El màxim de tempertura a la Sala Profe és temperatura24.00ºC ºC
# El mínim de tempertura a la Sala Profe és temperatura24.00ºC ºC

# %%
max_u = df['Sala Profe: Humitat'].max()
print("El màxim de humitat al Sala Profe és", max_u, "%")
min_u = df['Sala Profe: Humitat'].min()
print("El mínim de humitat al Sala Profe és", min_u, "%")
# Out:
# El màxim de humitat al Sala Profe és Humitat37.00% %
# El mínim de humitat al Sala Profe és Humitat36.00% %

# %%
max_u = df['Passadis: Temp'].max()
print("El màxim de tempertura al Passadis és", max_u, "ºC")
min_u = df['Passadis: Temp'].min()
print("El mínim de tempertura al Passadis és", min_u, "ºC")
# Out:
# El màxim de tempertura al Passadis és Temperatura24.00ºC ºC
# El mínim de tempertura al Passadis és Temperatura24.00ºC ºC

# %%
max_u = df['Passadis: Humitat'].max()
print("El màxim de humitat al Passadis és", max_u, "%")
min_u = df['Passadis: Humitat'].min()
print("El mínim de humitat al Passadis és", min_u, "%")
# Out:
# El màxim de humitat al Passadis és Humitat57.00% %
# El mínim de humitat al Passadis és Humitat57.00% %

# %%
import pandas as pd

# %%
df = pd.read_csv('programacion - Full 1 (2).csv')

# %%
print(df.head())
# Out:
#    Segons            A14: Temp   A14: Humitat          Pati: Temp  \
# 0        1  Temperatura25.00ºC  Humitat50.00%  Temperatura29.00ºC
# 1        2  Temperatura25.00ºC  Humitat50.00%  Temperatura29.00ºC
# 2        3  Temperatura25.00ºC  Humitat50.00%  Temperatura29.00ºC
# 3        4  Temperatura25.00ºC  Humitat50.00%  Temperatura29.00ºC
# 4        5  Temperatura25.00ºC  Humitat50.00%  Temperatura29.00ºC
#
#    Pati: Humitat          Bany: Temp  Bany: Humitat    Sala Profe: Temp  \
# 0  Humitat38.00%  Temperatura22.00ºC  humitat49.00%  temperatura24.00ºC
# 1  Humitat38.00%  Temperatura22.00ºC  humitat49.00%  temperatura24.00ºC
# 2  Humitat38.00%  Temperatura22.00ºC  humitat49.00%  temperatura24.00ºC
# 3  Humitat38.00%  Temperatura22.00ºC  humitat49.00%  temperatura24.00ºC
# 4  Humitat38.00%  Temperatura22.00ºC  humitat49.00%  temperatura24.00ºC
#
#   Sala Profe: Humitat      Passadis: Temp Passadis: Humitat
# 0       Humitat37.00%  Temperatura24.00ºC     Humitat57.00%
# ...

# %%
suma_u = df["A14: Temp"].sum()
promig_u = (suma_u/179)
suma_dos = df["Pati: Temp"].sum()
promig_dos = (suma_dos/179)
suma_tres = df["Bany: Temp"].sum()
promig_tres = (suma_tres/179)
suma_quatre = df["Sala Profe: Temp"].sum()
promig_quatre = (suma_quatre/179)
suma_cinc = df["Passadis: Temp"].sum()
promig_cinc = (suma_cinc/179)

suma_total = (promig_u + promig_dos + promig_tres + promig_quatre + promig_cinc)
promig = (suma_total/5)
promig_total = round(promig, 2)
print("El promig de la temperatura és", promig_total, "ºC")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-23a9b4966b9d> in <cell line: 0>()
#       1 suma_u = df["A14: Temp"].sum()
# ----> 2 promig_u = (suma_u/179)
#       3 suma_dos = df["Pati: Temp"].sum()
#       4 promig_dos = (suma_dos/179)
#       5 suma_tres = df["Bany: Temp"].sum()
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
from google.colab import files
import pandas as pd
archivo_subido = files.upload()
nombre_archivo = list(archivo_subido.keys())[0]
df = pd.read_csv(nombre_archivo)
(df)
# Out:
#      <input type="file" id="files-bc8c31f3-8414-4661-9ce8-0134f4889064" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc8c31f3-8414-4661-9ce8-0134f4889064">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
